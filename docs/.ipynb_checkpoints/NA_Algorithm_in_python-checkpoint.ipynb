# %% [markdown]
# # Neighborhood Algorithm in Python
#
# References:
#
#     Sambridge, M. (1999). Geophysical inversion with a neighbourhood
#     algorithm - I. Searching a parameter space. Geophysical Journal
#     International, 138(2), 479–494.

# %%
from pyNA import Sampler
import pandas as pd
import numpy as np

# %% [markdown]
# ## Test 1: Custom Objective function

# %%
def objective_function(inputs):
    return np.abs((inputs[:, 0] - 0.2)**2 + (inputs[:, 1] - 0.4)**2)

# %%
sampler = Sampler(objective_function=objective_function, 
                  n_initial=100,
                  n_samples=50,
                  n_resample=5,
                  n_iterations=20)

# %%
sampler.generate_ensemble()
# Out:
# iter 0, 100 models
# iter 1, 150 models
# iter 2, 200 models
# iter 3, 250 models
# iter 4, 300 models
# iter 5, 350 models
# iter 6, 400 models
# iter 7, 450 models
# iter 8, 500 models
# iter 9, 550 models
# iter 10, 600 models
# iter 11, 650 models
# iter 12, 700 models
# iter 13, 750 models
# iter 14, 800 models
# iter 15, 850 models
# iter 16, 900 models
# iter 17, 950 models
# iter 18, 1000 models
# iter 19, 1050 models

# %%
results = pd.DataFrame(sampler.dim_models, columns=["param1", "param2"])
results["misfit"] = sampler.misfits

# %%
results.head()
# Out:
#      param1    param2    misfit
# 0  0.123082  0.295877  0.016758
# 1  0.958118  0.706256  0.668536
# 2  0.410395  0.843051  0.240560
# 3  0.437372  0.452463  0.059098
# 4  0.342544  0.452016  0.023025

# %%
results.loc[results.misfit.argmin()]
# Out:
# param1    1.997201e-01
# param2    4.000159e-01
# misfit    7.861723e-08
# Name: 956, dtype: float64

# %%
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi, voronoi_plot_2d
vors = Voronoi(results[["param1", "param2"]])
fig = voronoi_plot_2d(vors, show_vertices=False)
fig.set_size_inches(10, 10)
best = results.loc[results.misfit.argmin()]
ax = plt.gca()
ax.scatter(best["param1"], best["param2"], color="black")
plt.xlim(sampler.lower_bounds[0], sampler.upper_bounds[0])
plt.ylim(sampler.lower_bounds[1], sampler.upper_bounds[1])
ax.set_aspect('equal')

# %%
results.param1.plot()
results.param2.plot()
# Out:
# <AxesSubplot:>

# %%
results.misfit.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Test2:  Rosenbrock Function

# %%
def rosenbrock(inputs, a=1, b=100):
    return (a - inputs[:, 0])**2 + b*(inputs[:, 1] - inputs[:, 0]**2)**2

# %%
sampler = Sampler(objective_function=rosenbrock,
                  lower_bounds=(-3, -3),
                  upper_bounds=(3.0, 3.0),
                  n_initial=100,
                  n_samples=70,
                  n_resample=10,
                  n_iterations=20)

# %%
sampler.generate_ensemble()
# Out:
# iter 0, 100 models
# iter 1, 170 models
# iter 2, 240 models
# iter 3, 310 models
# iter 4, 380 models
# iter 5, 450 models
# iter 6, 520 models
# iter 7, 590 models
# iter 8, 660 models
# iter 9, 730 models
# iter 10, 800 models
# iter 11, 870 models
# iter 12, 940 models
# iter 13, 1010 models
# iter 14, 1080 models
# iter 15, 1150 models
# iter 16, 1220 models
# iter 17, 1290 models
# iter 18, 1360 models
# iter 19, 1430 models

# %%
results = pd.DataFrame(sampler.dim_models, columns=["param1", "param2"])
results["misfit"] = sampler.misfits

# %%
results.head()
# Out:
#      param1    param2       misfit
# 0  1.767062 -2.314501  2956.695660
# 1 -1.982800 -1.656650  3131.633491
# 2  1.274921  1.284734    11.682555
# 3  1.135028 -1.977031  1066.249592
# 4  0.089227  1.723338   295.081060

# %%
results.loc[results.misfit.argmin()]
# Out:
# param1    1.013353
# param2    1.026421
# misfit    0.000200
# Name: 1241, dtype: float64

# %%
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi, voronoi_plot_2d
vors = Voronoi(results[["param1", "param2"]])
fig = voronoi_plot_2d(vors, show_vertices=False)
plt.xlim(sampler.lower_bounds[0], sampler.upper_bounds[0])
plt.ylim(sampler.lower_bounds[1], sampler.upper_bounds[1])
# Out:
# (-3.0, 3.0)

# %%
results.param1.plot()
results.param2.plot()
# Out:
# <AxesSubplot:>

# %%
results.misfit.plot()
# Out:
# <AxesSubplot:>
